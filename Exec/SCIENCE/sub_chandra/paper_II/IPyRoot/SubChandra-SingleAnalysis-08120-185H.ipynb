# %% [markdown]
# # Load and Configure

# %% [markdown]
# ---
# This section is for choosing a run to analyze and configuring the analysis

# %%
RUN_LABEL = '08120-108-185-3lev'
STAGE_DIR = '/u/sciteam/ajacobs/Projects/SubChandra/Runs'
SCRATCH_DIR = '/u/sciteam/ajacobs/scratch/sub_chandra'

# %% [markdown]
# ### Imports

# %%
#This loads matplotlib for inline plotting and also loads most of the popular scientific computing python packages with
#widely used naming convenctions.  e.g. numpy imported as np, matplotlib.pyplot as plt, etc... (see %pylab?)
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
#This means that modules will be automatically reloaded when changed.  
#Makes for swift exporatory development, probably a performance hit if using well-tested code.
# %load_ext autoreload
# %autoreload 2

# %%
import subchandra as sc
from IPython.display import HTML, display

# %% [markdown]
# # Run Setup

# %% [markdown]
# ---
# Plot information about the run's setup and initial conditions

# %%
r08120_185 = sc.SCSimulation(STAGE_DIR, SCRATCH_DIR, RUN_LABEL)
# Out:
# subchandra.py:1940: RuntimeWarning: divide by zero encountered in double_scalars
#   tnuc[1][i] = 3.4e-4 * np.exp(20./T8) * pow(rho6, -2.3)

# %%
r08120_185.plotInitModel(fontsize='x-large')
# Out:
# /u/sciteam/ajacobs/local/lib64/python2.6/site-packages/mpl_toolkits/__init__.py:2: UserWarning: Module dateutil was already imported from /u/sciteam/ajacobs/local/lib64/python2.6/site-packages/dateutil/__init__.pyc, but /usr/lib64/python2.6/site-packages is being added to sys.path
#   __import__('pkg_resources').declare_namespace(__name__)
# /u/sciteam/ajacobs/local/lib64/python2.6/site-packages/matplotlib/figure.py:1533: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
display(HTML(sc.display_parameters(STAGE_DIR, RUN_LABEL)))
# Out:
# <table border="1">
#   <tr>
#     <th>Model Label</th>
#     <th>08120-108-185-3lev</th>
#   </tr>
#   <tr>
#     <th>(Core, Shell) Mass [M$_\odot$]</th>
#     <td>( 0.8
# ,  0.12
# )</td>
#   </tr>
#   <tr>
#     <th>T$_{\mathrm{CO}}$ [K]</th>
#     <td> 100000000.0
# </td>
#   </tr>
#   <tr>
#     <th>T$_{\mathrm{base}}$ [K]</th>
#     <td> 185000000.0
# </td>
#   </tr>
#   <tr>
#     <th>$\rho_{\mathrm{base}}$ [$\times 10^5$ g cm$^{-3}$]</th>
#     <td>8.84059819127</td>
#   </tr>
#   <tr>
#     <th>R$_{\mathrm{max}}$ [cm]</th>
#     <td> 850000000.0d0
# </td>
#   </tr>
#   <tr>
#     <th>anelastic_cutoff [g cm$^{-3}$]</th>
#     <td> 103000.0d0
# </td>
#   </tr>
#   <tr>
#     <th>base_cutoff_density [g cm$^{-3}$]</th>
#     <td> 1.d4
# </td>
#   </tr>
#   <tr>
#     <th>species_pred_type</th>
#     <td> 1
# </td>
#   </tr>
#   <tr>
#     <th>octant</th>
#     <td> .true.
# </td>
#   </tr>
#   <tr>
#     <th>Levs</th>
#     <td> 3
# </td>
#   </tr>
#   <tr>
#     <th>$\Delta x_\mathrm{fine}$ [km]</th>
#     <td>8.30078125</td>
#   </tr>
# </table>

# %% [markdown]
# # Time-Series

# %% [markdown]
# ---
# This section is for plotting time-series data

# %%
r08120_185.printTimestampOverview()
# Out:
# Step        Time (s)    CO/He r (cm)     l_conv (cm)   U_conv (cm/s)          H (cm)
# ------------------------------------------------------------------------------------
#    0          0.0000       4.495e+08       1.046e+08       4.453e+04       5.229e+07
#   86          5.3647       4.495e+08       1.046e+08       4.474e+04       5.229e+07
#   93         10.4556       4.495e+08       1.046e+08       4.748e+04       5.229e+07
#   98         15.0779       4.495e+08       1.046e+08       5.682e+04       5.229e+07
#  107         20.0514       4.495e+08       1.046e+08       9.133e+04       5.229e+07
#  129         25.1218       4.495e+08       1.054e+08       2.128e+05       5.229e+07
#  177         30.0789       4.495e+08       1.062e+08       4.567e+05       5.229e+07
#  243         35.0478       4.495e+08       1.071e+08       6.767e+05       5.312e+07
#  310         40.0780       4.495e+08       1.071e+08       8.287e+05       5.312e+07
#  373         45.0840       4.495e+08       1.079e+08       9.687e+05       5.312e+07
#  436         50.0229       4.495e+08       1.079e+08       1.128e+06       5.312e+07
#  505         55.0164       4.495e+08       1.087e+08       1.347e+06       5.312e+07
#  582         60.0311       4.495e+08       1.096e+08       1.645e+06       5.312e+07
#  670         65.0077       4.495e+08       1.096e+08       2.022e+06       5.312e+07
#  772         70.0168       4.495e+08       1.096e+08       2.478e+06       5.312e+07
#  872         75.0083       4.495e+08       1.104e+08       2.948e+06       5.312e+07
#  977         80.0113       4.495e+08       1.096e+08       3.375e+06       5.396e+07
# 1089         85.0002       4.495e+08       1.096e+08       3.706e+06       5.396e+07
# 1203         90.0173       4.495e+08       1.096e+08       3.958e+06       5.396e+07
# 1329         95.0341       4.495e+08       1.096e+08       4.149e+06       5.396e+07
# 1458        100.0287       4.487e+08       1.112e+08       4.264e+06       5.396e+07
# 1590        105.0145       4.487e+08       1.112e+08       4.374e+06       5.396e+07
# 1717        110.0213       4.487e+08       1.121e+08       4.468e+06       5.396e+07
# 1855        115.0266       4.487e+08       1.121e+08       4.533e+06       5.396e+07
# 1991        120.0153       4.487e+08       1.121e+08       4.579e+06       5.396e+07
# 2130        125.0343       4.487e+08       1.129e+08        4.63e+06       5.396e+07
# 2265        130.0305       4.478e+08       1.137e+08       4.698e+06       5.396e+07
# 2415        135.0118       4.478e+08       1.146e+08       4.826e+06       5.396e+07
# 2559        140.0303       4.478e+08       1.146e+08       4.993e+06       5.396e+07
# 2705        145.0330       4.478e+08       1.137e+08       5.185e+06       5.396e+07
# 2860        150.0269       4.478e+08       1.146e+08        5.38e+06       5.396e+07
# 3034        155.0056       4.478e+08       1.154e+08        5.55e+06       5.396e+07
# 3216        160.0220       4.478e+08       1.146e+08       5.711e+06       5.396e+07
# 3374        165.0275       4.478e+08       1.146e+08       5.853e+06       5.396e+07
# 3565        170.0185       4.478e+08       1.154e+08       5.995e+06       5.396e+07
# 3753        175.0075       4.478e+08       1.146e+08        6.14e+06       5.396e+07
# 3946        180.0204        4.47e+08       1.154e+08       6.307e+06       5.396e+07
# 4156        185.0238        4.47e+08       1.162e+08       6.505e+06       5.396e+07
# 4368        190.0184        4.47e+08       1.162e+08       6.682e+06       5.479e+07
# 4589        195.0062        4.47e+08       1.162e+08       6.843e+06       5.479e+07
# 4809        200.0014        4.47e+08       1.162e+08       7.024e+06       5.479e+07
# 5076        205.0023        4.47e+08        1.17e+08       7.122e+06       5.479e+07
# 5310        210.0004        4.47e+08        1.17e+08       7.195e+06       5.479e+07
# 5565        215.0107        4.47e+08        1.17e+08       7.387e+06       5.479e+07
# 5814        220.0191        4.47e+08        1.17e+08       7.678e+06       5.479e+07
# 6079        225.0066        4.47e+08       1.179e+08       7.943e+06       5.479e+07
# 6324        230.0186        4.47e+08       1.179e+08       8.168e+06       5.479e+07
# 6569        235.0066        4.47e+08       1.179e+08        8.39e+06       5.479e+07
# 6825        240.0051        4.47e+08       1.179e+08       8.678e+06       5.479e+07

# %%
r08120_185.plotTimeSeries()

# %% [markdown]
# # Outcome Analysis

# %% [markdown]
# ---
# Determine outcome (localized runaway, quasi-equilibrium, convective runaway)

# %%
r08120_185.printOutcome()
# Out:
# Outcome |
#  timepeak | dt |
#  Tpeak | <Tpeak> | <rho_peak> | <r_peak> | <tconv> | (t_peak-50)/tconv
# ignition |
#  242.1318178 -2.126683682
#  1372221888.0 218056136.851 1036516.30279 446997070.312 27.3174508168 7.03329966946

# %% [markdown]
# # Hotspot

# %% [markdown]
# ---
# Hotspot characterization

# %%
r08120_185.plotHotspots(2396, reset=True)

# %% [markdown]
# # Convection

# %% [markdown]
# ---
# Convection characterization

# %%
run1_08050 = sc.SCSimulation(STAGE_DIR, SCRATCH_DIR, RUN_LABEL)

# %%
run1_08050.plotSnapshot(2199)

# %% [markdown]
# Timescales

# %%
run1_08050.printTimestampOverview()

# %%
run1_08050.plotTimescales(1262)
