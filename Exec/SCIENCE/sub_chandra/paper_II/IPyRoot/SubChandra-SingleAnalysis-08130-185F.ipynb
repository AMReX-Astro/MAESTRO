# %% [markdown]
# # Load and Configure

# %% [markdown]
# ---
# This section is for choosing a run to analyze and configuring the analysis

# %%
RUN_LABEL = '08130-107-185-4lev-full'
STAGE_DIR = '/u/sciteam/ajacobs/Projects/SubChandra/Runs'
SCRATCH_DIR = '/u/sciteam/ajacobs/scratch/sub_chandra'

# %% [markdown]
# ### Imports

# %%
#This loads matplotlib for inline plotting and also loads most of the popular scientific computing python packages with
#widely used naming convenctions.  e.g. numpy imported as np, matplotlib.pyplot as plt, etc... (see %pylab?)
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
#This means that modules will be automatically reloaded when changed.  
#Makes for swift exporatory development, probably a performance hit if using well-tested code.
# %load_ext autoreload
# %autoreload 2

# %%
import subchandra as sc
from IPython.display import HTML, display

# %% [markdown]
# # Run Setup

# %% [markdown]
# ---
# Plot information about the run's setup and initial conditions

# %%
r08130_185F = sc.SCSimulation(STAGE_DIR, SCRATCH_DIR, RUN_LABEL)
# Out:
# subchandra.py:1940: RuntimeWarning: divide by zero encountered in double_scalars
#   tnuc[1][i] = 3.4e-4 * np.exp(20./T8) * pow(rho6, -2.3)

# %%
r08130_185F.plotInitModel(fontsize='x-large')
# Out:
# /u/sciteam/ajacobs/local/lib64/python2.6/site-packages/mpl_toolkits/__init__.py:2: UserWarning: Module dateutil was already imported from /u/sciteam/ajacobs/local/lib64/python2.6/site-packages/dateutil/__init__.pyc, but /usr/lib64/python2.6/site-packages is being added to sys.path
#   __import__('pkg_resources').declare_namespace(__name__)
# /u/sciteam/ajacobs/local/lib64/python2.6/site-packages/matplotlib/figure.py:1533: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
display(HTML(sc.display_parameters(STAGE_DIR, RUN_LABEL)))
# Out:
# /u/sciteam/ajacobs/local/lib64/python2.6/site-packages/IPython/extensions/autoreload.py:380: UserWarning: Module dateutil was already imported from /u/sciteam/ajacobs/local/lib64/python2.6/site-packages/dateutil/__init__.pyc, but /usr/lib64/python2.6/site-packages is being added to sys.path
#   module = reload(module)
# <table border="1">
#   <tr>
#     <th>Model Label</th>
#     <th>08130-107-185-4lev-full</th>
#   </tr>
#   <tr>
#     <th>(Core, Shell) Mass [M$_\odot$]</th>
#     <td>( 0.8
# ,  0.13
# )</td>
#   </tr>
#   <tr>
#     <th>T$_{\mathrm{CO}}$ [K]</th>
#     <td> 10000000.0
# </td>
#   </tr>
#   <tr>
#     <th>T$_{\mathrm{base}}$ [K]</th>
#     <td> 185000000.0
# </td>
#   </tr>
#   <tr>
#     <th>$\rho_{\mathrm{base}}$ [$\times 10^5$ g cm$^{-3}$]</th>
#     <td>10.7413216903</td>
#   </tr>
#   <tr>
#     <th>R$_{\mathrm{max}}$ [cm]</th>
#     <td> 1620000000.0d0
# </td>
#   </tr>
#   <tr>
#     <th>anelastic_cutoff [g cm$^{-3}$]</th>
#     <td> 125000.0d0
# </td>
#   </tr>
#   <tr>
#     <th>base_cutoff_density [g cm$^{-3}$]</th>
#     <td> 1.d4
# </td>
#   </tr>
#   <tr>
#     <th>species_pred_type</th>
#     <td> 1
# </td>
#   </tr>
#   <tr>
#     <th>octant</th>
#     <td> .false.
# </td>
#   </tr>
#   <tr>
#     <th>Levs</th>
#     <td> 4
# </td>
#   </tr>
#   <tr>
#     <th>$\Delta x_\mathrm{fine}$ [km]</th>
#     <td>7.91015625</td>
#   </tr>
# </table>

# %% [markdown]
# # Time-Series

# %% [markdown]
# ---
# This section is for plotting time-series data

# %%
r08130_185F.printTimestampOverview()
# Out:
# Step        Time (s)    CO/He r (cm)     l_conv (cm)   U_conv (cm/s)          H (cm)
# ------------------------------------------------------------------------------------
#    0          0.0000       4.252e+08       1.013e+08       4.481e+04       5.062e+07
#   87          5.4857       4.252e+08       1.013e+08        4.54e+04       5.062e+07
#   94         10.6913       4.252e+08       1.013e+08       5.085e+04       5.062e+07
#  102         15.1956       4.252e+08        1.02e+08        7.25e+04       5.142e+07
#  122         20.0805       4.252e+08        1.02e+08       1.769e+05       5.142e+07
#  178         25.0091       4.252e+08       1.036e+08        5.33e+05       5.142e+07
#  272         30.0487       4.252e+08       1.044e+08       8.891e+05       5.142e+07
#  369         35.0407       4.252e+08       1.052e+08       1.111e+06       5.221e+07
#  454         40.0202       4.252e+08        1.06e+08       1.338e+06       5.221e+07
#  550         45.0343       4.252e+08       1.068e+08       1.673e+06       5.221e+07
#  667         50.0336       4.252e+08       1.068e+08        2.17e+06       5.221e+07
#  802         55.0339       4.252e+08       1.068e+08       2.837e+06       5.221e+07
#  948         60.0190       4.252e+08       1.068e+08       3.554e+06       5.221e+07
# 1100         65.0187       4.252e+08       1.076e+08       4.156e+06       5.221e+07
# 1260         70.0144       4.244e+08       1.068e+08       4.569e+06       5.221e+07
# 1419         75.0244       4.244e+08       1.076e+08       4.831e+06       5.221e+07
# 1587         80.0218       4.244e+08       1.092e+08       4.985e+06       5.221e+07
# 1766         85.0152       4.244e+08       1.092e+08        5.15e+06       5.221e+07
# 1944         90.0141       4.244e+08       1.092e+08       5.326e+06       5.221e+07
# 2121         95.0264       4.244e+08         1.1e+08        5.47e+06         5.3e+07
# 2299        100.0138       4.236e+08       1.107e+08       5.634e+06         5.3e+07
# 2490        105.0090       4.236e+08       1.115e+08       5.846e+06         5.3e+07

# %%
r08130_185F.plotTimeSeries()

# %% [markdown]
# # Outcome Analysis

# %% [markdown]
# ---
# Determine outcome (localized runaway, quasi-equilibrium, convective runaway)

# %%
r08130_185F.printOutcome()
# Out:
# WARNING: Couldn't find a slice near (< 3 s) ignition time! dt:  -35.519869691
# Outcome |
#  timepeak | dt |
#  Tpeak | <Tpeak> | <rho_peak> | <r_peak> | <tconv> | (t_peak-50)/tconv
# ignition |
#  140.5288375 -35.519869691
#  375997452.4 203766169.572 1210233.74883 425961914.062 25.9036457284 3.49482997294

# %% [markdown]
# # Hotspot

# %% [markdown]
# ---
# Hotspot characterization

# %%
r08130_185F.plotHotspots(2396, reset=True)
# Out:
# Building hotspots array for step  2396
# Min, Max temp of 1226624 hottest cells: 204412528.0, 236356944.0
# Critical density range: [0.904928484063, 1.60807680524]
# mark A
# mark B
# mark C
# mark D
# mark E
# mark FF

# %% [markdown]
# # Convection

# %% [markdown]
# ---
# Convection characterization

# %%
run1_08050 = sc.SCSimulation(STAGE_DIR, SCRATCH_DIR, RUN_LABEL)

# %%
run1_08050.plotSnapshot(2199)

# %% [markdown]
# Timescales

# %%
run1_08050.printTimestampOverview()

# %%
run1_08050.plotTimescales(1262)
