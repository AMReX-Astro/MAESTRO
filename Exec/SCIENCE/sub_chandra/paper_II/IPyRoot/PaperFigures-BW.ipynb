# %% [markdown]
# This notebook is a collection of figures used in sub-Chandrasekhar paper II.  These plots are mostly
# modified versions of plots found in other notebooks.

# %%
STAGE_DIR = '/ccs/home/ajacobs/Projects/SubChandra/Runs'
SCRATCH_DIR = '/tmp/work/ajacobs/sub_chandra'
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
import subchandra as sc
from IPython.display import Image, Pretty, SVG

# %% [markdown]
# # Typical Initial Model

# %%
run1_12050 = sc.SCSimulation(STAGE_DIR, SCRATCH_DIR, '12050-107-175-3lev')
# Out:
# subchandra.py:848: RuntimeWarning: divide by zero encountered in double_scalars
#   tnuc[1][i] = 3.4e-4 * np.exp(20./T8) * pow(rho6, -2.3)

# %%
run1_12050.plotInitModel(writefile=True, fontsize='x-large')
# Out:
# /opt/sw/xk6/python_matplotlib/1.2.1/python2.6.8_numpy1.7.1/lib64/python2.6/site-packages/matplotlib/figure.py:1533: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# # Grid Structure

# %% [markdown]
# This figure was made using Gimp and VisIt 2.5.2.  It needs some work, but is what I got for the moment.  Also, IPython can't display eps or pdf it seems, so this is a png convesion of the eps.

# %%
Image(filename='PaperFigs/grid.png')

# %% [markdown]
# # Minimum Mass Graph

# %%
p = sc.SCPlotter()
p.plotMinMass([0.8, 1.0, 1.1], [0.12, 0.04, 0.03], fontsize='x-large')

# %% [markdown]
# # Hotspot Projection
