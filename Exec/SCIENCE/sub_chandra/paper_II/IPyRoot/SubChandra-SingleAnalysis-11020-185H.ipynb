# %% [markdown]
# # Load and Configure

# %% [markdown]
# ---
# This section is for choosing a run to analyze and configuring the analysis

# %%
RUN_LABEL = '11020-108-185-4lev'
STAGE_DIR = '/u/sciteam/ajacobs/Projects/SubChandra/Runs'
SCRATCH_DIR = '/u/sciteam/ajacobs/scratch/sub_chandra'

# %% [markdown]
# ### Imports

# %%
#This loads matplotlib for inline plotting and also loads most of the popular scientific computing python packages with
#widely used naming convenctions.  e.g. numpy imported as np, matplotlib.pyplot as plt, etc... (see %pylab?)
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
#This means that modules will be automatically reloaded when changed.  
#Makes for swift exporatory development, probably a performance hit if using well-tested code.
# %load_ext autoreload
# %autoreload 2

# %%
import subchandra as sc
from IPython.display import HTML, display

# %% [markdown]
# # Run Setup

# %% [markdown]
# ---
# Plot information about the run's setup and initial conditions

# %%
r11020_185H = sc.SCSimulation(STAGE_DIR, SCRATCH_DIR, RUN_LABEL)
# Out:
# subchandra.py:1415: RuntimeWarning: divide by zero encountered in double_scalars
#   tnuc[1][i] = 3.4e-4 * np.exp(20./T8) * pow(rho6, -2.3)

# %%
r11020_185H.plotInitModel(fontsize='x-large')
# Out:
# /u/sciteam/ajacobs/local/lib64/python2.6/site-packages/mpl_toolkits/__init__.py:2: UserWarning: Module dateutil was already imported from /u/sciteam/ajacobs/local/lib64/python2.6/site-packages/dateutil/__init__.pyc, but /usr/lib64/python2.6/site-packages is being added to sys.path
#   __import__('pkg_resources').declare_namespace(__name__)
# /u/sciteam/ajacobs/local/lib64/python2.6/site-packages/matplotlib/figure.py:1533: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
display(HTML(sc.display_parameters(STAGE_DIR, RUN_LABEL)))
# Out:
# /u/sciteam/ajacobs/local/lib64/python2.6/site-packages/IPython/extensions/autoreload.py:380: UserWarning: Module dateutil was already imported from /u/sciteam/ajacobs/local/lib64/python2.6/site-packages/dateutil/__init__.pyc, but /usr/lib64/python2.6/site-packages is being added to sys.path
#   module = reload(module)
# <table border="1">
#   <tr>
#     <th>Model Label</th>
#     <th>11020-108-185-4lev</th>
#   </tr>
#   <tr>
#     <th>(Core, Shell) Mass [M$_\odot$]</th>
#     <td>( 1.1
# ,  0.02
# )</td>
#   </tr>
#   <tr>
#     <th>T$_{\mathrm{CO}}$ [K]</th>
#     <td> 100000000.0
# </td>
#   </tr>
#   <tr>
#     <th>T$_{\mathrm{base}}$ [K]</th>
#     <td> 185000000.0
# </td>
#   </tr>
#   <tr>
#     <th>$\rho_{\mathrm{base}}$ [$\times 10^5$ g cm$^{-3}$]</th>
#     <td>3.61318830946</td>
#   </tr>
#   <tr>
#     <th>R$_{\mathrm{max}}$ [cm]</th>
#     <td> 690000000.0d0
# </td>
#   </tr>
#   <tr>
#     <th>anelastic_cutoff [g cm$^{-3}$]</th>
#     <td> 43000.0d0
# </td>
#   </tr>
#   <tr>
#     <th>base_cutoff_density [g cm$^{-3}$]</th>
#     <td> 1.d4
# </td>
#   </tr>
#   <tr>
#     <th>species_pred_type</th>
#     <td> 1
# </td>
#   </tr>
#   <tr>
#     <th>octant</th>
#     <td> .true.
# </td>
#   </tr>
#   <tr>
#     <th>Levs</th>
#     <td> 4
# </td>
#   </tr>
#   <tr>
#     <th>$\Delta x_\mathrm{fine}$ [km]</th>
#     <td>3.369140625</td>
#   </tr>
# </table>

# %% [markdown]
# # Time-Series

# %% [markdown]
# ---
# This section is for plotting time-series data

# %%
r11020_185H.printTimestampOverview()
# Out:
# Step        Time (s)    CO/He r (cm)     l_conv (cm)   U_conv (cm/s)          H (cm)
# ------------------------------------------------------------------------------------
#    0          0.0000       4.051e+08       4.043e+07       1.645e+04       2.123e+07
# 2209        220.0016       4.051e+08       4.211e+07       4.943e+05       2.156e+07
# 2297        225.0407       4.051e+08        4.11e+07        5.06e+05       2.156e+07
# 2378        230.0412       4.051e+08        4.11e+07       5.218e+05       2.156e+07
# 2455        235.0094       4.051e+08        4.11e+07       5.363e+05       2.156e+07
# 2530        240.0283       4.051e+08        4.11e+07       5.466e+05       2.156e+07
# 2606        245.0156       4.051e+08        4.11e+07       5.535e+05       2.156e+07
# 2680        250.0495       4.051e+08       4.852e+07       5.276e+05       2.156e+07
# 2752        255.0706       4.051e+08       4.852e+07       5.314e+05       2.156e+07
# 2821        260.0435       4.051e+08        4.11e+07       5.714e+05       2.156e+07
# 2895        265.0420       4.051e+08        4.11e+07       5.803e+05       2.156e+07
# 2970        270.0486       4.051e+08       4.986e+07       5.494e+05       2.156e+07
# 3042        275.0277       4.051e+08       4.548e+07       5.902e+05       2.156e+07
# 3120        280.0706       4.051e+08       4.986e+07       5.836e+05       2.156e+07
# 3206        285.0172       4.051e+08       4.986e+07        5.99e+05       2.156e+07
# 3295        290.0481       4.051e+08       5.121e+07       5.922e+05       2.156e+07
# 3392        295.0411       4.051e+08       5.121e+07       6.076e+05       2.156e+07
# 3507        300.0082       4.051e+08       5.155e+07       6.192e+05       2.156e+07
# 3633        305.0004       4.051e+08       4.178e+07       6.412e+05       2.156e+07
# 3761        310.0355       4.051e+08       4.178e+07       6.509e+05       2.156e+07
# 3881        315.0048       4.051e+08       4.178e+07       6.625e+05       2.156e+07
# 4006        320.0139       4.051e+08       4.178e+07       6.794e+05       2.156e+07
# 4119        325.0299       4.051e+08       5.222e+07       6.841e+05       2.156e+07
# 4241        330.0150       4.051e+08       5.222e+07       7.027e+05       2.156e+07
# 4359        335.0011       4.051e+08       4.178e+07       7.479e+05       2.156e+07
# 4476        340.0080       4.051e+08       4.211e+07        7.72e+05       2.156e+07
# 4589        345.0034       4.051e+08       4.245e+07       7.917e+05        2.19e+07
# 4697        350.0101       4.051e+08       4.279e+07       8.063e+05        2.19e+07
# 4801        355.0453       4.051e+08       4.211e+07       8.142e+05        2.19e+07
# 4920        360.0235       4.048e+08       5.256e+07        8.01e+05        2.19e+07
# 5030        365.0096       4.048e+08       5.256e+07       8.055e+05        2.19e+07
# 5133        370.0413       4.048e+08       5.256e+07       8.059e+05        2.19e+07
# 5232        375.0350       4.048e+08       5.256e+07       8.156e+05        2.19e+07
# 5327        380.0004       4.048e+08        5.29e+07       8.161e+05        2.19e+07
# 5422        385.0159       4.048e+08        5.29e+07       8.147e+05        2.19e+07
# 5514        390.0234       4.048e+08        5.29e+07       8.295e+05        2.19e+07
# 5609        395.0342       4.048e+08        5.29e+07       8.513e+05        2.19e+07

# %%
r11020_185H.plotTimeSeries()

# %% [markdown]
# # Hotspot

# %% [markdown]
# ---
# Hotspot characterization

# %%
r11020_185H.plotHotspots(2396, reset=True)

# %% [markdown]
# # Convection

# %% [markdown]
# ---
# Convection characterization

# %%
run1_08050 = sc.SCSimulation(STAGE_DIR, SCRATCH_DIR, RUN_LABEL)

# %%
run1_08050.plotSnapshot(2199)

# %% [markdown]
# Timescales

# %%
run1_08050.printTimestampOverview()

# %%
run1_08050.plotTimescales(1262)
