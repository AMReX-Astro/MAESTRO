# %% [markdown]
# # Load & Configure

# %% [markdown]
# ---
# Load and configure in preparation for carrying out the critical density

# %%
RUN_LABEL = '11030-108-185-4lev'
STAGE_DIR = '/u/sciteam/ajacobs/Projects/SubChandra/Runs'
SCRATCH_DIR = '/u/sciteam/ajacobs/scratch/sub_chandra'

# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
import subchandra as sc
from IPython.display import HTML, display
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %% [markdown]
# # Calculate

# %% [markdown]
# ---
# Calculate the laterally averaged density at the location of the peak laterally averaged temperature at the time of ignition for all runs that ignite.  Fit this to exponential for expression of temperature-dependent critical density.

# %%
r08120_185H = sc.SCSimulation(STAGE_DIR, SCRATCH_DIR, '08120-108-185-3lev')
# Out:
# subchandra.py:1421: RuntimeWarning: divide by zero encountered in double_scalars
#   tnuc[1][i] = 3.4e-4 * np.exp(20./T8) * pow(rho6, -2.3)

# %%
r11030_185H = sc.SCSimulation(STAGE_DIR, SCRATCH_DIR, '11030-108-185-4lev')
# Out:
# subchandra.py:1421: RuntimeWarning: divide by zero encountered in double_scalars
#   tnuc[1][i] = 3.4e-4 * np.exp(20./T8) * pow(rho6, -2.3)

# %%
r12020_175 = sc.SCSimulation(STAGE_DIR, SCRATCH_DIR, "12020-107-175-4lev")
# Out:
# subchandra.py:1421: RuntimeWarning: divide by zero encountered in double_scalars
#   tnuc[1][i] = 3.4e-4 * np.exp(20./T8) * pow(rho6, -2.3)

# %%
r12020_175H = sc.SCSimulation(STAGE_DIR, SCRATCH_DIR, "12020-108-175-4lev")

# %%
r12030_175 = sc.SCSimulation(STAGE_DIR, SCRATCH_DIR, "12030-107-175-4lev")

# %%
r12030_175H = sc.SCSimulation(STAGE_DIR, SCRATCH_DIR, "12030-108-175-4lev")

# %%
scp = sc.SCPlotter()

# %%
sims = [r08120_185H, r11030_185H, r12020_175, r12020_175H, r12030_175, r12030_175H]

# %%
scp.plotTempTimeSeries(r12030_175H)

# %%
sims = [r08120_185H, r11030_185H, r12020_175, r12020_175H, r12030_175, r12030_175H]
scp.printHotRhoTemp(sims)
# Out:
# step | time | <rho>_base | <temp>_base
# (6825, 240.005134118, 1036516.30279, 218056136.85100001)
# (15244, 315.00210613199999, 773212.47292500001, 242990164.18000001)
# (14850, 400.00248811400002, 971243.72804199997, 231721276.88600001)
# (14414, 420.00247492099999, 942366.84762000002, 248008199.01699999)
# (5747, 120.400799648, 1454119.99279, 217770436.54899999)
# (5406, 123.001325429, 1418363.041, 225946389.516)

# %%
sims = [r08120_185H, r11030_185H, r12020_175, r12020_175H]
scp.plotHotRhoTemp(sims)
