# %% [markdown]
# # Load and Configure

# %% [markdown]
# ---
# This section is for choosing a run to analyze and configuring the analysis

# %%
RUN_LABEL = '12020-107-175-4lev'
STAGE_DIR = '/u/sciteam/ajacobs/Projects/SubChandra/Runs'
SCRATCH_DIR = '/u/sciteam/ajacobs/scratch/sub_chandra'

# %% [markdown]
# ### Imports

# %%
#This loads matplotlib for inline plotting and also loads most of the popular scientific computing python packages with
#widely used naming convenctions.  e.g. numpy imported as np, matplotlib.pyplot as plt, etc... (see %pylab?)
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
#This means that modules will be automatically reloaded when changed.  
#Makes for swift exporatory development, probably a performance hit if using well-tested code.
# %load_ext autoreload
# %autoreload 2

# %%
import subchandra as sc
from IPython.display import HTML, display

# %% [markdown]
# # Run Setup

# %% [markdown]
# ---
# Plot information about the run's setup and initial conditions

# %%
r12020_175 = sc.SCSimulation(STAGE_DIR, SCRATCH_DIR, RUN_LABEL)
# Out:
# subchandra.py:1940: RuntimeWarning: divide by zero encountered in double_scalars
#   tnuc[1][i] = 3.4e-4 * np.exp(20./T8) * pow(rho6, -2.3)

# %%
r12020_175.plotInitModel(fontsize='x-large')
# Out:
# /u/sciteam/ajacobs/local/lib64/python2.6/site-packages/mpl_toolkits/__init__.py:2: UserWarning: Module dateutil was already imported from /u/sciteam/ajacobs/local/lib64/python2.6/site-packages/dateutil/__init__.pyc, but /usr/lib64/python2.6/site-packages is being added to sys.path
#   __import__('pkg_resources').declare_namespace(__name__)
# /u/sciteam/ajacobs/local/lib64/python2.6/site-packages/matplotlib/figure.py:1533: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
display(HTML(sc.display_parameters(STAGE_DIR, RUN_LABEL)))
# Out:
# /u/sciteam/ajacobs/local/lib64/python2.6/site-packages/IPython/extensions/autoreload.py:380: UserWarning: Module dateutil was already imported from /u/sciteam/ajacobs/local/lib64/python2.6/site-packages/dateutil/__init__.pyc, but /usr/lib64/python2.6/site-packages is being added to sys.path
#   module = reload(module)
# <table border="1">
#   <tr>
#     <th>Model Label</th>
#     <th>12020-107-175-4lev</th>
#   </tr>
#   <tr>
#     <th>(Core, Shell) Mass [M$_\odot$]</th>
#     <td>( 1.2
# ,  0.02
# )</td>
#   </tr>
#   <tr>
#     <th>T$_{\mathrm{CO}}$ [K]</th>
#     <td> 10000000.0
# </td>
#   </tr>
#   <tr>
#     <th>T$_{\mathrm{base}}$ [K]</th>
#     <td> 175000000.0
# </td>
#   </tr>
#   <tr>
#     <th>$\rho_{\mathrm{base}}$ [$\times 10^5$ g cm$^{-3}$]</th>
#     <td>6.76329673219</td>
#   </tr>
#   <tr>
#     <th>R$_{\mathrm{max}}$ [cm]</th>
#     <td> 530000000.0d0
# </td>
#   </tr>
#   <tr>
#     <th>anelastic_cutoff [g cm$^{-3}$]</th>
#     <td> 87000.0d0
# </td>
#   </tr>
#   <tr>
#     <th>base_cutoff_density [g cm$^{-3}$]</th>
#     <td> 1.d4
# </td>
#   </tr>
#   <tr>
#     <th>species_pred_type</th>
#     <td> 1
# </td>
#   </tr>
#   <tr>
#     <th>octant</th>
#     <td> .true.
# </td>
#   </tr>
#   <tr>
#     <th>Levs</th>
#     <td> 4
# </td>
#   </tr>
#   <tr>
#     <th>$\Delta x_\mathrm{fine}$ [km]</th>
#     <td>2.587890625</td>
#   </tr>
# </table>

# %% [markdown]
# # Time-Series

# %% [markdown]
# ---
# This section is for plotting time-series data

# %%
r12020_175.printTimestampOverview()
# Out:
# Step        Time (s)    CO/He r (cm)     l_conv (cm)   U_conv (cm/s)          H (cm)
# ------------------------------------------------------------------------------------
#    0          0.0000       3.159e+08       2.769e+07            9966       1.527e+07
#  102          5.0079       3.159e+08       2.769e+07            9571       1.527e+07
#  114         10.2148       3.159e+08       2.769e+07        1.03e+04       1.527e+07
#  127         15.1350       3.159e+08       2.769e+07       1.311e+04       1.527e+07
#  144         20.0069       3.159e+08       2.769e+07       2.257e+04       1.527e+07
#  179         25.0733       3.159e+08       2.769e+07       5.491e+04       1.527e+07
#  239         30.0299       3.159e+08       2.769e+07       1.456e+05       1.527e+07
#  324         35.0249       3.159e+08       2.795e+07       3.697e+05       1.527e+07
# 4568        255.0046       3.161e+08       3.054e+07       1.082e+06       1.579e+07
# 4690        260.0130       3.161e+08       3.105e+07       1.118e+06       1.579e+07
# 4815        265.0060       3.161e+08       3.468e+07       1.072e+06       1.579e+07
# 4945        270.0237       3.161e+08       3.597e+07       1.083e+06       1.604e+07
# 5077        275.0307       3.161e+08       3.597e+07       1.131e+06       1.604e+07
# 5223        280.0093       3.161e+08       3.727e+07       1.151e+06       1.604e+07
# 5367        285.0019       3.161e+08       3.752e+07       1.198e+06       1.604e+07
# 5539        290.0331       3.161e+08       3.778e+07        1.26e+06       1.604e+07
# 5698        295.0266       3.161e+08       3.804e+07       1.347e+06        1.63e+07
# 5865        300.0253       3.161e+08       3.545e+07       1.545e+06        1.63e+07
# 6039        305.0091       3.161e+08       3.597e+07        1.73e+06       1.656e+07
# 6236        310.0011       3.161e+08       4.011e+07       1.898e+06       1.682e+07
# 6484        315.0110       3.161e+08       4.037e+07       2.328e+06       1.682e+07
# 6778        320.0060       3.161e+08       4.063e+07       2.722e+06       1.682e+07
# 7119        325.0027       3.161e+08       3.778e+07       3.174e+06       1.682e+07
# 7473        330.0033       3.161e+08       3.804e+07       3.256e+06       1.708e+07
# 7823        335.0086       3.161e+08        3.83e+07       3.409e+06       1.708e+07
# 8184        340.0099       3.161e+08        4.27e+07       3.354e+06       1.708e+07
# 8583        345.0026       3.161e+08       4.167e+07       3.672e+06       1.708e+07
# 8986        350.0119       3.161e+08       4.192e+07       3.837e+06       1.734e+07
# 9394        355.0050       3.161e+08       4.192e+07        4.06e+06       1.734e+07
# 9850        360.0067       3.161e+08       4.218e+07       4.338e+06       1.734e+07
# 10345        365.0095       3.161e+08       4.348e+07       4.455e+06       1.734e+07
# 10870        370.0034       3.161e+08       3.727e+07       5.295e+06       1.734e+07
# 11447        375.0078       3.161e+08       3.752e+07        5.67e+06        1.76e+07
# 12048        380.0050       3.161e+08       3.752e+07       6.027e+06        1.76e+07
# 12666        385.0070       3.161e+08       3.804e+07       6.487e+06        1.76e+07
# 13344        390.0056       3.161e+08       3.934e+07       6.931e+06        1.76e+07
# 14062        395.0034       3.159e+08        2.07e+06       1.704e+05       2.019e+07
# 14850        400.0025       3.156e+08       2.588e+06       4.746e+05       2.019e+07
# 16734        410.0044       3.151e+08       5.693e+06       1.503e+06       2.044e+07

# %%
r12020_175.plotTimeSeries()

# %% [markdown]
# # Outcome Analysis

# %% [markdown]
# ---
# Determine outcome (localized runaway, quasi-equilibrium, convective runaway)

# %%
r12020_175.printOutcome()
# Out:
# Outcome |
#  timepeak | dt |
#  Tpeak | <Tpeak> | <rho_peak> | <r_peak> | <tconv> | (t_peak-50)/tconv
# ignition |
#  411.4037176 -1.399271072
#  1094419263.0 240974974.752 996337.444851 316369628.906 28.0562713857 12.8813880017

# %% [markdown]
# # Hotspot

# %% [markdown]
# ---
# Hotspot characterization

# %%
r12020_175.plotHotspots(2396, reset=True)

# %% [markdown]
# # Convection

# %% [markdown]
# ---
# Convection characterization

# %%
run1_08050 = sc.SCSimulation(STAGE_DIR, SCRATCH_DIR, RUN_LABEL)

# %%
run1_08050.plotSnapshot(2199)

# %% [markdown]
# Timescales

# %%
run1_08050.printTimestampOverview()

# %%
run1_08050.plotTimescales(1262)
