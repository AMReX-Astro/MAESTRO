# %% [markdown]
# # Load and Configure

# %% [markdown]
# ---
# This section is for choosing a run to analyze and configuring the analysis

# %%
RUN_LABEL = '12020-108-175-4lev'
STAGE_DIR = '/u/sciteam/ajacobs/Projects/SubChandra/Runs'
SCRATCH_DIR = '/u/sciteam/ajacobs/scratch/sub_chandra'

# %% [markdown]
# ### Imports

# %%
#This loads matplotlib for inline plotting and also loads most of the popular scientific computing python packages with
#widely used naming convenctions.  e.g. numpy imported as np, matplotlib.pyplot as plt, etc... (see %pylab?)
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
#This means that modules will be automatically reloaded when changed.  
#Makes for swift exporatory development, probably a performance hit if using well-tested code.
# %load_ext autoreload
# %autoreload 2

# %%
import subchandra as sc
from IPython.display import HTML, display

# %% [markdown]
# # Run Setup

# %% [markdown]
# ---
# Plot information about the run's setup and initial conditions

# %%
r12020_175H = sc.SCSimulation(STAGE_DIR, SCRATCH_DIR, RUN_LABEL)
# Out:
# subchandra.py:1940: RuntimeWarning: divide by zero encountered in double_scalars
#   tnuc[1][i] = 3.4e-4 * np.exp(20./T8) * pow(rho6, -2.3)

# %%
r12020_175H.plotInitModel(fontsize='x-large')
# Out:
# /u/sciteam/ajacobs/local/lib64/python2.6/site-packages/mpl_toolkits/__init__.py:2: UserWarning: Module dateutil was already imported from /u/sciteam/ajacobs/local/lib64/python2.6/site-packages/dateutil/__init__.pyc, but /usr/lib64/python2.6/site-packages is being added to sys.path
#   __import__('pkg_resources').declare_namespace(__name__)
# /u/sciteam/ajacobs/local/lib64/python2.6/site-packages/matplotlib/figure.py:1533: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
display(HTML(sc.display_parameters(STAGE_DIR, RUN_LABEL)))
# Out:
# /u/sciteam/ajacobs/local/lib64/python2.6/site-packages/IPython/extensions/autoreload.py:380: UserWarning: Module dateutil was already imported from /u/sciteam/ajacobs/local/lib64/python2.6/site-packages/dateutil/__init__.pyc, but /usr/lib64/python2.6/site-packages is being added to sys.path
#   module = reload(module)
# <table border="1">
#   <tr>
#     <th>Model Label</th>
#     <th>12020-108-175-4lev</th>
#   </tr>
#   <tr>
#     <th>(Core, Shell) Mass [M$_\odot$]</th>
#     <td>( 1.2
# ,  0.02
# )</td>
#   </tr>
#   <tr>
#     <th>T$_{\mathrm{CO}}$ [K]</th>
#     <td> 100000000.0
# </td>
#   </tr>
#   <tr>
#     <th>T$_{\mathrm{base}}$ [K]</th>
#     <td> 175000000.0
# </td>
#   </tr>
#   <tr>
#     <th>$\rho_{\mathrm{base}}$ [$\times 10^5$ g cm$^{-3}$]</th>
#     <td>6.24090029375</td>
#   </tr>
#   <tr>
#     <th>R$_{\mathrm{max}}$ [cm]</th>
#     <td> 550000000.0d0
# </td>
#   </tr>
#   <tr>
#     <th>anelastic_cutoff [g cm$^{-3}$]</th>
#     <td> 80000.0d0
# </td>
#   </tr>
#   <tr>
#     <th>base_cutoff_density [g cm$^{-3}$]</th>
#     <td> 1.d4
# </td>
#   </tr>
#   <tr>
#     <th>species_pred_type</th>
#     <td> 1
# </td>
#   </tr>
#   <tr>
#     <th>octant</th>
#     <td> .true.
# </td>
#   </tr>
#   <tr>
#     <th>Levs</th>
#     <td> 4
# </td>
#   </tr>
#   <tr>
#     <th>$\Delta x_\mathrm{fine}$ [km]</th>
#     <td>2.685546875</td>
#   </tr>
# </table>

# %% [markdown]
# # Time-Series

# %% [markdown]
# ---
# This section is for plotting time-series data

# %%
r12020_175H.printTimestampOverview()
# Out:
# Step        Time (s)    CO/He r (cm)     l_conv (cm)   U_conv (cm/s)          H (cm)
# ------------------------------------------------------------------------------------
#    0          0.0000        3.27e+08       2.847e+07       1.036e+04       1.558e+07
#  102          5.2818        3.27e+08       2.847e+07            9955       1.558e+07
#  113         10.0281        3.27e+08       2.847e+07       1.054e+04       1.558e+07
#  125         15.2143        3.27e+08       2.847e+07       1.284e+04       1.558e+07
#  140         20.1158        3.27e+08       2.847e+07       1.963e+04       1.558e+07
#  165         25.0534        3.27e+08       2.847e+07       4.045e+04       1.558e+07
#  210         30.0244        3.27e+08       2.847e+07       9.917e+04       1.558e+07
#  284         35.0020        3.27e+08       2.874e+07         2.5e+05       1.584e+07
#  380         40.0112        3.27e+08       2.874e+07       5.052e+05       1.584e+07
# 4354        265.0106        3.27e+08       3.169e+07       8.681e+05       1.611e+07
# 4453        270.0379        3.27e+08       3.572e+07       8.548e+05       1.611e+07
# 4556        275.0333        3.27e+08       3.894e+07       8.151e+05       1.611e+07
# 4666        280.0376        3.27e+08       3.894e+07       8.186e+05       1.611e+07
# 4764        285.0380        3.27e+08       3.894e+07       8.233e+05       1.611e+07
# 4861        290.0474        3.27e+08       3.894e+07       8.368e+05       1.611e+07
# 4958        295.0431        3.27e+08       3.921e+07       8.482e+05       1.638e+07
# 5054        300.0072        3.27e+08       3.921e+07       8.631e+05       1.638e+07
# 5157        305.0426        3.27e+08       3.921e+07       8.892e+05       1.638e+07
# 5261        310.0072        3.27e+08       3.921e+07       9.289e+05       1.638e+07
# 5372        315.0393        3.27e+08       3.921e+07       9.656e+05       1.638e+07
# 5481        320.0083        3.27e+08       3.948e+07       9.923e+05       1.638e+07
# 5597        325.0051        3.27e+08       3.948e+07       1.018e+06       1.638e+07
# 5719        330.0211        3.27e+08       5.371e+05       2.538e+05       1.719e+07
# 5846        335.0172        3.27e+08       1.611e+06       4.588e+05       1.746e+07
# 5978        340.0084        3.27e+08       2.148e+06       7.944e+05       1.746e+07
# 6116        345.0288        3.27e+08       4.297e+07       1.242e+06       1.746e+07
# 6334        350.0044        3.27e+08       3.867e+07       1.933e+06       1.772e+07
# 6648        355.0111        3.27e+08       3.921e+07       3.073e+06       1.772e+07
# 7020        360.0081        3.27e+08       3.948e+07       3.818e+06       1.772e+07
# 7409        365.0064        3.27e+08       3.706e+07       4.104e+06       1.799e+07
# 7804        370.0046       3.272e+08       4.485e+07       3.699e+06       1.799e+07
# 8237        375.0109       3.272e+08       4.512e+07       4.252e+06       1.799e+07
# 8717        380.0062        3.27e+08       4.512e+07       4.687e+06       1.799e+07
# 9246        385.0016        3.27e+08       4.001e+07       5.531e+06       1.826e+07
# 9793        390.0048       3.267e+08       3.894e+07       6.085e+06       1.826e+07
# 10376        395.0028       3.264e+08       3.921e+07       6.623e+06       1.826e+07
# 10994        400.0016       3.262e+08       4.055e+07       7.126e+06       1.853e+07
# 11693        405.0057       3.259e+08       4.028e+07       7.959e+06       1.853e+07
# 12464        410.0004       3.256e+08       4.163e+07       8.834e+06       1.853e+07
# 13377        415.0056       3.254e+08       3.491e+06       5.565e+05       2.148e+07
# 14414        420.0025       3.251e+08       1.047e+07       7.038e+05       2.229e+07

# %%
r12020_175H.plotTimeSeries()

# %% [markdown]
# # Outcome Analysis

# %% [markdown]
# ---
# Determine outcome (localized runaway, quasi-equilibrium, convective runaway)

# %%
r12020_175H.printOutcome(ig_temp=5.0e8)
# Out:
# Outcome |
#  timepeak | dt |
#  Tpeak | <Tpeak> | <rho_peak> | <r_peak> | <tconv> | (t_peak-50)/tconv
# ignition |
#  419.4218628 0.580612121
#  950024989.7 248008199.017 942366.84762 326159667.969 35.850313827 10.3045642664

# %% [markdown]
# # Hotspot

# %% [markdown]
# ---
# Hotspot characterization

# %%
r12020_175H.plotHotspots(2396, reset=True)

# %% [markdown]
# # Convection

# %% [markdown]
# ---
# Convection characterization

# %%
run1_08050 = sc.SCSimulation(STAGE_DIR, SCRATCH_DIR, RUN_LABEL)

# %%
run1_08050.plotSnapshot(2199)

# %% [markdown]
# Timescales

# %%
run1_08050.printTimestampOverview()

# %%
run1_08050.plotTimescales(1262)
